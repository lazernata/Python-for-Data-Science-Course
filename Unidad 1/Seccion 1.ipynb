# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\nlazareva\Downloads\Datasets-Data-Science-con-Python-ADR\1.3\Info_pais.csv', encoding = 'ISO-8859-1',delimiter=';')

# %%
df.head()
# Out:
#             País   Poblacion  Renta per capita Esperanza de vida
# 0  United States   325084756             59939              78,9
# 1          China  1421021791              8612              76,7
# 2          Japan   127502725             38214              84,5
# 3        Germany    82658409             44680              81,2
# 4          India  1338676785              1980              69,4

# %%
dr_orden = df.sort_values('Esperanza de vida', ascending = True)

# %%
anyo = [2020,2021,2022]

# %%
valor = [5,6,7]

# %%
plt.plot(anyo,valor)

# %%
plt.scatter(anyo,valor)

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.scatter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20420\775846558.py in ?()
# ----> 1 df.scatter()
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'

# %%
df1 = pd.read_csv(r'C:\Users\nlazareva\Downloads\Datasets-Data-Science-con-Python-ADR\1.4\SP500_data.csv', encoding = 'ISO-8859-1',delimiter=',')

# %%
df1.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  1927-12-30  17.660000  17.660000  17.660000  17.660000  17.660000       0
# 1  1928-01-03  17.760000  17.760000  17.760000  17.760000  17.760000       0
# 2  1928-01-04  17.719999  17.719999  17.719999  17.719999  17.719999       0
# 3  1928-01-05  17.549999  17.549999  17.549999  17.549999  17.549999       0
# 4  1928-01-06  17.660000  17.660000  17.660000  17.660000  17.660000       0

# %%
df1['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df1.index = df1['Date']
