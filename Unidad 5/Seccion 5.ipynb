# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\nlazareva\Downloads\PEATONES_2020.csv', delimiter=';', encoding='ISO-8859-1', index_col=2, nrows=10000, )

# %%
df
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00       497                1   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00       244                1   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00       179                1   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00       174                1   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00       131                1   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA04_PM01  15/02/2020   9:00:00       392                1   Centro
# PERM_PEA04_PM01  15/02/2020   9:15:00       453                1   Centro
# PERM_PEA04_PM01  15/02/2020   9:30:00       362                1   Centro
# PERM_PEA04_PM01  15/02/2020   9:45:00       390                1   Centro
# PERM_PEA04_PM01  15/02/2020  10:00:00       309                1   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# ...

# %%
df1 = pd.read_csv(r'C:\Users\nlazareva\Downloads\PEATONES_2020_mod.csv', delimiter=';', encoding='ISO-8859-1', index_col=2)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288755 entries, PERM_PEA02_PM01 to PERM_PEA19_PM01
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FECHA                    288755 non-null  object
#  1   HORA                     288755 non-null  object
#  2   PEATONES                 288752 non-null  float64
#  3   NÚMERO_DISTRITO          284872 non-null  float64
#  4   DISTRITO                 284872 non-null  object
#  5   NOMBRE_VIAL              284872 non-null  object
#  6   NÚMERO                   284872 non-null  float64
#  7   CÓDIGO_POSTAL            284872 non-null  float64
#  8   OBSERVACIONES_DIRECCION  284872 non-null  object
#  9   LATITUD                  284872 non-null  object
#  10  LONGITUD                 284872 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 26.4+ MB

# %%
df1
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  30/06/2020  22:45:00     565.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:00:00     415.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:15:00     551.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:30:00     456.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:45:00     532.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# ...

# %%
df1.count()
# Out:
# FECHA                      288755
# HORA                       288755
# PEATONES                   288752
# NÚMERO_DISTRITO            284872
# DISTRITO                   284872
# NOMBRE_VIAL                284872
# NÚMERO                     284872
# CÓDIGO_POSTAL              284872
# OBSERVACIONES_DIRECCION    284872
# LATITUD                    284872
# LONGITUD                   284872
# dtype: int64

# %%
df1['PEATONES'].median()
# Out:
# 373.0

# %%
df1['PEATONES'].mean()
# Out:
# 451.455397711531

# %%
df1['PEATONES'].quantile(0.9)
# Out:
# 956.0

# %%
df1['FECHA'].min(), df1['FECHA'].max()
# Out:
# ('01/01/2020', '31/05/2020')

# %%
df1.describe()
# Out:
#             PEATONES  NÚMERO_DISTRITO         NÚMERO  CÓDIGO_POSTAL
# count  288752.000000    284872.000000  284872.000000  284872.000000
# mean      451.455398         2.648786      27.223181   28010.099557
# std       366.229982         2.999406      24.671420       4.296102
# min         1.000000         1.000000       1.000000   28001.000000
# 25%       142.000000         1.000000       4.000000   28005.000000
# 50%       373.000000         1.000000      22.000000   28012.000000
# 75%       680.000000         2.000000      37.000000   28013.000000
# max      4759.000000        10.000000      91.000000   28015.000000

# %%
df1['Peatones_acum'] = df1['PEATONES'].cumsum()

# %%
df1['Peatones_acum']
# Out:
# IDENTIFICADOR
# PERM_PEA02_PM01          497.0
# PERM_PEA02_PM01          741.0
# PERM_PEA02_PM01          920.0
# PERM_PEA02_PM01         1094.0
# PERM_PEA02_PM01         1225.0
#                       ...
# PERM_PEA19_PM01    130356695.0
# PERM_PEA19_PM01    130357110.0
# PERM_PEA19_PM01    130357661.0
# PERM_PEA19_PM01    130358117.0
# PERM_PEA19_PM01    130358649.0
# Name: Peatones_acum, Length: 288755, dtype: float64

# %%
df1.shape, df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288755 entries, PERM_PEA02_PM01 to PERM_PEA19_PM01
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FECHA                    288755 non-null  object
#  1   HORA                     288755 non-null  object
#  2   PEATONES                 288752 non-null  float64
#  3   NÚMERO_DISTRITO          284872 non-null  float64
#  4   DISTRITO                 284872 non-null  object
#  5   NOMBRE_VIAL              284872 non-null  object
#  6   NÚMERO                   284872 non-null  float64
#  7   CÓDIGO_POSTAL            284872 non-null  float64
#  8   OBSERVACIONES_DIRECCION  284872 non-null  object
#  9   LATITUD                  284872 non-null  object
#  10  LONGITUD                 284872 non-null  object
#  11  Peatones_acum            288752 non-null  float64
# dtypes: float64(5), object(7)
# memory usage: 36.7+ MB
# ...

# %%
df1_1 = df1.drop_duplicates()

# %%
df1_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288755 entries, PERM_PEA02_PM01 to PERM_PEA19_PM01
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FECHA                    288755 non-null  object
#  1   HORA                     288755 non-null  object
#  2   PEATONES                 288752 non-null  float64
#  3   NÚMERO_DISTRITO          284872 non-null  float64
#  4   DISTRITO                 284872 non-null  object
#  5   NOMBRE_VIAL              284872 non-null  object
#  6   NÚMERO                   284872 non-null  float64
#  7   CÓDIGO_POSTAL            284872 non-null  float64
#  8   OBSERVACIONES_DIRECCION  284872 non-null  object
#  9   LATITUD                  284872 non-null  object
#  10  LONGITUD                 284872 non-null  object
#  11  Peatones_acum            288752 non-null  float64
# dtypes: float64(5), object(7)
# memory usage: 36.7+ MB

# %%
df1_2 = df1_1.dropna()

# %%
df1_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 284869 entries, PERM_PEA02_PM01 to PERM_PEA19_PM01
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FECHA                    284869 non-null  object
#  1   HORA                     284869 non-null  object
#  2   PEATONES                 284869 non-null  float64
#  3   NÚMERO_DISTRITO          284869 non-null  float64
#  4   DISTRITO                 284869 non-null  object
#  5   NOMBRE_VIAL              284869 non-null  object
#  6   NÚMERO                   284869 non-null  float64
#  7   CÓDIGO_POSTAL            284869 non-null  float64
#  8   OBSERVACIONES_DIRECCION  284869 non-null  object
#  9   LATITUD                  284869 non-null  object
#  10  LONGITUD                 284869 non-null  object
#  11  Peatones_acum            284869 non-null  float64
# dtypes: float64(5), object(7)
# memory usage: 28.3+ MB

# %%
df2 = df1[(df1['FECHA'] > '01/01/2020') & (df1['FECHA'] < '05/01/2020')]
df2
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  02/01/2020   0:00:00     406.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   0:15:00     273.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   0:30:00     208.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   0:45:00     250.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   1:00:00     144.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  04/06/2020  22:45:00     554.0              1.0   Centro
# PERM_PEA19_PM01  04/06/2020  23:00:00     538.0              1.0   Centro
# PERM_PEA19_PM01  04/06/2020  23:15:00     433.0              1.0   Centro
# PERM_PEA19_PM01  04/06/2020  23:30:00     469.0              1.0   Centro
# PERM_PEA19_PM01  04/06/2020  23:45:00     517.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# ...

# %%
df2 = df2[df2['DISTRITO'] =='Centro']
df2
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  02/01/2020   0:00:00     406.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   0:15:00     273.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   0:30:00     208.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   0:45:00     250.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   1:00:00     144.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  04/06/2020  22:45:00     554.0              1.0   Centro
# PERM_PEA19_PM01  04/06/2020  23:00:00     538.0              1.0   Centro
# PERM_PEA19_PM01  04/06/2020  23:15:00     433.0              1.0   Centro
# PERM_PEA19_PM01  04/06/2020  23:30:00     469.0              1.0   Centro
# PERM_PEA19_PM01  04/06/2020  23:45:00     517.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# ...

# %%
iris = pd.read_csv(r'C:\Users\nlazareva\Downloads\iris_dataset.csv', delimiter=',', encoding='ISO-8859-1', nrows=10000, )
iris
# Out:
#      longitud_sépalo   anchura_sépalo  longitud_pétalo  anchura_pétalo  \
# 0                5.1              3.5              1.4             0.2
# 1                4.9              3.0              1.4             0.2
# 2                4.7              3.2              1.3             0.2
# 3                4.6              3.1              1.5             0.2
# 4                5.0              3.6              1.4             0.2
# ..               ...              ...              ...             ...
# 145              6.7              3.0              5.2             2.3
# 146              6.3              2.5              5.0             1.9
# 147              6.5              3.0              5.2             2.0
# 148              6.2              3.4              5.4             2.3
# 149              5.9              3.0              5.1             1.8
#
#               clase
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
import numpy as np
iris['Area'] = iris.apply(lambda x:x['longitud_pétalo']*x['anchura_pétalo']*np.pi, axis=1)
iris
# Out:
#      longitud_sépalo   anchura_sépalo  longitud_pétalo  anchura_pétalo  \
# 0                5.1              3.5              1.4             0.2
# 1                4.9              3.0              1.4             0.2
# 2                4.7              3.2              1.3             0.2
# 3                4.6              3.1              1.5             0.2
# 4                5.0              3.6              1.4             0.2
# ..               ...              ...              ...             ...
# 145              6.7              3.0              5.2             2.3
# 146              6.3              2.5              5.0             1.9
# 147              6.5              3.0              5.2             2.0
# 148              6.2              3.4              5.4             2.3
# 149              5.9              3.0              5.1             1.8
#
#               clase       Area
# 0       Iris-setosa   0.879646
# 1       Iris-setosa   0.879646
# ...

# %%
np.median(iris['Area'])
# Out:
# 17.640042749906687

# %%
iris['Area'].quantile(0.9)
# Out:
# 38.9337577559383

# %%
df1 = pd.read_csv(r'C:\Users\nlazareva\Downloads\PEATONES_2020_mod.csv', delimiter=';', encoding='ISO-8859-1', index_col=2)

# %%
df1
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  30/06/2020  22:45:00     565.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:00:00     415.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:15:00     551.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:30:00     456.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:45:00     532.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# ...

# %%
df1.groupby('DISTRITO')['PEATONES'].agg('mean')
# Out:
# DISTRITO
# Arganzuela         651.036304
# Centro             488.248612
# Chamberí           269.302136
# Latina              71.679353
# Moncloa-Aravaca    360.899778
# Name: PEATONES, dtype: float64

# %%
df1.groupby(['DISTRITO', 'FECHA'])['PEATONES'].agg('mean', 'min')
# Out:
# DISTRITO         FECHA
# Arganzuela       01/01/2020    589.885417
#                  01/02/2020    579.602094
#                  01/03/2020    670.229167
#                  01/04/2020    573.463542
#                  01/05/2020    585.791667
#                                   ...
# Moncloa-Aravaca  30/05/2020    358.291667
#                  30/06/2020    261.562500
#                  31/01/2020    325.760417
#                  31/03/2020    266.500000
#                  31/05/2020    447.739583
# Name: PEATONES, Length: 860, dtype: float64

# %%
df1.groupby(['FECHA', 'DISTRITO'])['PEATONES'].agg(lambda x:(x*1.1).max())
# Out:
# FECHA       DISTRITO
# 01/01/2020  Arganzuela         1734.7
#             Centro             1577.4
# 01/02/2020  Arganzuela         1989.9
#             Centro             1624.7
#             Chamberí           1164.9
#                                 ...
# 31/05/2020  Arganzuela         1824.9
#             Centro             1635.7
#             Chamberí            986.7
#             Latina              134.2
#             Moncloa-Aravaca     864.6
# Name: PEATONES, Length: 860, dtype: float64

# %%
df2 = pd.read_csv(r'C:\Users\nlazareva\Downloads\PEATONES_2020_mod_2.csv', delimiter=';', encoding='ISO-8859-1')
df_pob = pd.read_csv(r'C:\Users\nlazareva\Downloads\Distrito_poblacion.csv', delimiter=';', encoding='ISO-8859-1')

# %%
df2
# Out:
#              FECHA      HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO  \
# 0       01/01/2020   0:00:00  PERM_PEA02_PM01     497.0              1.0
# 1       01/01/2020   0:15:00  PERM_PEA02_PM01     244.0              1.0
# 2       01/01/2020   0:30:00  PERM_PEA02_PM01     179.0              1.0
# 3       01/01/2020   0:45:00  PERM_PEA02_PM01     174.0              1.0
# 4       01/01/2020   1:00:00  PERM_PEA02_PM01     131.0              1.0
# ...            ...       ...              ...       ...              ...
# 288750  30/06/2020  22:45:00  PERM_PEA19_PM01     565.0              1.0
# 288751  30/06/2020  23:00:00  PERM_PEA19_PM01     415.0              1.0
# 288752  30/06/2020  23:15:00  PERM_PEA19_PM01     551.0              1.0
# 288753  30/06/2020  23:30:00  PERM_PEA19_PM01     456.0              1.0
# 288754  30/06/2020  23:45:00  PERM_PEA19_PM01     532.0              1.0
#
#        DISTRITO       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# ...

# %%
pip install pymysql
# Out:
# ...
#   Obtaining dependency information for pymysql from https://files.pythonhosted.org/packages/e5/30/20467e39523d0cfc2b6227902d3687a16364307260c75e6a1cb4422b0c62/PyMySQL-1.1.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/44.8 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/44.8 kB ? eta -:--:--
#    ------------------------------------ --- 41.0/44.8 kB 487.6 kB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 kB 442.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_pob
# Out:
#           DISTRITO  Población_Distrito
# 0       Arganzuela              151965
# 1           Centro              149718
# 2         Chamberí              137401
# 3  Moncloa-Aravaca              116903
# 4           Latina              233808

# %%
df_comb = df2.merge(df_pob, on = 'DISTRITO', how = 'inner')
df_comb
# Out:
#              FECHA      HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO  \
# 0       01/01/2020   0:00:00  PERM_PEA02_PM01     497.0              1.0
# 1       01/01/2020   0:15:00  PERM_PEA02_PM01     244.0              1.0
# 2       01/01/2020   0:30:00  PERM_PEA02_PM01     179.0              1.0
# 3       01/01/2020   0:45:00  PERM_PEA02_PM01     174.0              1.0
# 4       01/01/2020   1:00:00  PERM_PEA02_PM01     131.0              1.0
# ...            ...       ...              ...       ...              ...
# 284867  30/06/2020  22:45:00  PERM_PEA17_PM01     809.0              2.0
# 284868  30/06/2020  23:00:00  PERM_PEA17_PM01     809.0              2.0
# 284869  30/06/2020  23:15:00  PERM_PEA17_PM01     726.0              2.0
# 284870  30/06/2020  23:30:00  PERM_PEA17_PM01     671.0              2.0
# 284871  30/06/2020  23:45:00  PERM_PEA17_PM01     785.0              2.0
#
#           DISTRITO              NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# ...

# %%
df_comb['KPI_peat_pob'] = df_comb['PEATONES']/df_comb['Población_Distrito']
df_comb
# Out:
#              FECHA      HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO  \
# 0       01/01/2020   0:00:00  PERM_PEA02_PM01     497.0              1.0
# 1       01/01/2020   0:15:00  PERM_PEA02_PM01     244.0              1.0
# 2       01/01/2020   0:30:00  PERM_PEA02_PM01     179.0              1.0
# 3       01/01/2020   0:45:00  PERM_PEA02_PM01     174.0              1.0
# 4       01/01/2020   1:00:00  PERM_PEA02_PM01     131.0              1.0
# ...            ...       ...              ...       ...              ...
# 284867  30/06/2020  22:45:00  PERM_PEA17_PM01     809.0              2.0
# 284868  30/06/2020  23:00:00  PERM_PEA17_PM01     809.0              2.0
# 284869  30/06/2020  23:15:00  PERM_PEA17_PM01     726.0              2.0
# 284870  30/06/2020  23:30:00  PERM_PEA17_PM01     671.0              2.0
# 284871  30/06/2020  23:45:00  PERM_PEA17_PM01     785.0              2.0
#
#           DISTRITO              NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# ...

# %%
df_comb.groupby('DISTRITO')['KPI_peat_pob'].agg('max')
# Out:
# DISTRITO
# Arganzuela         0.026809
# Centro             0.031786
# Chamberí           0.008413
# Latina             0.000920
# Moncloa-Aravaca    0.008811
# Name: KPI_peat_pob, dtype: float64

# %%
from sqlalchemy import create_engine
import pymysql

# %%
import requests
import pandas as pd
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_average_wage'
r = requests.get(url)
df_list = pd.read_html(r.text)
df_list[1]
# Out:
#                      Country  \
# 0              Switzerland *
# 1               Luxembourg *
# 2            United States *
# 3                  Iceland *
# 4                   Norway *
# 5                  Denmark *
# 6                   Canada *
# 7                  Ireland *
# 8              Netherlands *
# 9                  Belgium *
# 10                 Austria *
# 11          United Kingdom *
# 12                 Finland *
# 13                 Germany *
# 14                  Sweden *
# 15                  France *
# 16                  Israel *
# 17                   Italy *
# 18                Slovenia *
# 19                   Spain *
# 20                  Cyprus *
# 21                Portugal *
# 22                 Estonia *
# 23          Czech Republic *
# 24               Lithuania *
# 25                Slovakia *
# 26                  Greece *
# 27                  Poland *
# 28                 Romania *
# 29                  Latvia *
# 30                 Hungary *
# ...
