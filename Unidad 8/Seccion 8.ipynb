# %%
import pandas as pd
import seaborn as sns
from scipy import stats

# %%
total_historico = pd.read_excel(r"C:\Users\nlazareva\Downloads\Datos_poblacin_activa.xlsx", sheet_name = 'Total Histórico')
total_historico.head()
# Out:
#   Periodo  Total Activos Periodo num  Periodo num_int
# 0  2020T1        22994.2  2020-01-01           202001
# 1  2019T4        23158.8  2019-10-01           201910
# 2  2019T3        23088.7  2019-07-01           201907
# 3  2019T2        23035.5  2019-04-01           201904
# 4  2019T1        22825.4  2019-01-01           201901

# %%
sns.regplot(data = total_historico, x = 'Periodo num_int', y = 'Total Activos', scatter = True, color = 'blue', label = 'order 1')
# Out:
# <Axes: xlabel='Periodo num_int', ylabel='Total Activos'>

# %%
pendiente, intercepto, r_value, p_value, std_err = stats.linregress(total_historico['Periodo num_int'], total_historico['Total Activos'])

# %%
sns.regplot(data = total_historico, x = 'Periodo num_int', y = 'Total Activos', scatter = True, 
            color = 'blue', label = 'order 1', line_kws = {'label':"y={0:.1f}x+{1:.1f}".format(pendiente,intercepto)})
# Out:
# <Axes: xlabel='Periodo num_int', ylabel='Total Activos'>

# %%
y_202201 = 1.8*202201-340650.1
y_202201
# Out:
# 23311.70000000001

# %%
df_peatones = pd.read_csv(r"C:\Users\nlazareva\Downloads\PEATONES_2020_mod_5.csv", encoding = 'ISO-8859-1', delimiter = ';')
df_peatones.head()
# Out:
#         FECHA     HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# 0  01/01/2020  0:00:00  PERM_PEA02_PM01     497.0              1.0   Centro
# 1  01/01/2020  0:15:00  PERM_PEA02_PM01     244.0              1.0   Centro
# 2  01/01/2020  0:30:00  PERM_PEA02_PM01     179.0              1.0   Centro
# 3  01/01/2020  0:45:00  PERM_PEA02_PM01     174.0              1.0   Centro
# 4  01/01/2020  1:00:00  PERM_PEA02_PM01     131.0              1.0   Centro
#
#         NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL         OBSERVACIONES_DIRECCION  \
# 0  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 1  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 2  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 3  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 4  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
#
#       LATITUD    LONGITUD
# 0  40,4220090  -3,7008917
# ...

# %%
sns.violinplot(data = df_peatones, x = 'DISTRITO', y = 'PEATONES')
# Out:
# <Axes: xlabel='DISTRITO', ylabel='PEATONES'>

# %%
df_peatones[df_peatones['DISTRITO']=='Chamberí'].groupby(['HORA'])['PEATONES'].agg('mean').plot()
# Out:
# <Axes: xlabel='HORA'>

# %%
df = pd.read_csv(r"C:\Users\nlazareva\Downloads\datasets_1489_2704_autompg_cont.csv", encoding = 'ISO-8859-1', delimiter = ',')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name continent
# 0          70       1  chevrolet chevelle malibu   America
# 1          70       1          buick skylark 320   America
# 2          70       1         plymouth satellite   America
# 3          70       1              amc rebel sst   America
# 4          70       1                ford torino   America

# %%
corr80 = df[df['model year']==80].corr(numeric_only=True)
sns.heatmap(corr80, xticklabels = corr80.columns.values, yticklabels = corr80.columns.values)
# Out:
# <Axes: >
