# %%
import requests
import pandas as pd
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_average_wage'
r = requests.get(url)
df_list = pd.read_html(r.text)
df_list[1]
# Out:
#                      Country  \
# 0              Switzerland *
# 1               Luxembourg *
# 2            United States *
# 3                  Iceland *
# 4                   Norway *
# 5                  Denmark *
# 6                   Canada *
# 7                  Ireland *
# 8              Netherlands *
# 9                  Belgium *
# 10                 Austria *
# 11          United Kingdom *
# 12                 Finland *
# 13                 Germany *
# 14                  Sweden *
# 15                  France *
# 16                  Israel *
# 17                   Italy *
# 18                Slovenia *
# 19                   Spain *
# 20                  Cyprus *
# 21                Portugal *
# 22                 Estonia *
# 23          Czech Republic *
# 24               Lithuania *
# 25                Slovakia *
# 26                  Greece *
# 27                  Poland *
# 28                 Romania *
# 29                  Latvia *
# 30                 Hungary *
# ...

# %%
pip install boto3
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting boto3
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/3d/c8/df9bbe980e31a06b1af5188813d06c388951c42522bac845da981d0e5645/boto3-1.34.59-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for botocore<1.35.0,>=1.34.59 from https://files.pythonhosted.org/packages/45/e9/3483693208da74b5503886c0846bf48f62a864b7897767c27cc04f5cd5e8/botocore-1.34.59-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for s3transfer<0.11.0,>=0.10.0 from https://files.pythonhosted.org/packages/12/bb/7e7912e18cd558e7880d9b58ffc57300b2c28ffba9882b3a54ba5ce3ebc4/s3transfer-0.10.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/139.3 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/139.3 kB ? eta -:--:--
#    ----------------- ---------------------- 61.4/139.3 kB 1.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\nlazareva\Downloads\SP500_data.csv', delimiter=',', encoding='ISO-8859-1')
df
# Out:
#              Date         Open         High          Low        Close  \
# 0      1927-12-30    17.660000    17.660000    17.660000    17.660000
# 1      1928-01-03    17.760000    17.760000    17.760000    17.760000
# 2      1928-01-04    17.719999    17.719999    17.719999    17.719999
# 3      1928-01-05    17.549999    17.549999    17.549999    17.549999
# 4      1928-01-06    17.660000    17.660000    17.660000    17.660000
# ...           ...          ...          ...          ...          ...
# 23186  2020-04-23  2810.419922  2844.899902  2794.260010  2797.800049
# 23187  2020-04-24  2812.639893  2842.709961  2791.760010  2836.739990
# 23188  2020-04-27  2854.649902  2887.719971  2852.889893  2878.479980
# 23189  2020-04-28  2909.959961  2921.149902  2860.709961  2863.389893
# 23190  2020-04-29  2918.459961  2954.860107  2912.159912  2939.510010
#
#          Adj Close      Volume
# 0        17.660000           0
# 1        17.760000           0
# ...

# %%
df['Var_dia'] = (df['Close'] - df['Open'])/df['Open'] * 100
df
# Out:
#              Date         Open         High          Low        Close  \
# 0      1927-12-30    17.660000    17.660000    17.660000    17.660000
# 1      1928-01-03    17.760000    17.760000    17.760000    17.760000
# 2      1928-01-04    17.719999    17.719999    17.719999    17.719999
# 3      1928-01-05    17.549999    17.549999    17.549999    17.549999
# 4      1928-01-06    17.660000    17.660000    17.660000    17.660000
# ...           ...          ...          ...          ...          ...
# 23186  2020-04-23  2810.419922  2844.899902  2794.260010  2797.800049
# 23187  2020-04-24  2812.639893  2842.709961  2791.760010  2836.739990
# 23188  2020-04-27  2854.649902  2887.719971  2852.889893  2878.479980
# 23189  2020-04-28  2909.959961  2921.149902  2860.709961  2863.389893
# 23190  2020-04-29  2918.459961  2954.860107  2912.159912  2939.510010
#
#          Adj Close      Volume   Var_dia
# 0        17.660000           0  0.000000
# 1        17.760000           0  0.000000
# ...

# %%
df.to_excel(r'C:\Users\nlazareva\Downloads\S&P500_v2.xlsx', sheet_name = 'Evolucion')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.to_excel(r'C:\Users\nlazareva\Downloads\S&P500_v2.xlsx', sheet_name = 'Evolucion')
#
# NameError: name 'df' is not defined
