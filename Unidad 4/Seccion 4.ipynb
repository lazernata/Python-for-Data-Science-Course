# %%
import numpy as np
def area(a,b):
    res = (a*b)/2
    return res[res>10]

# %%
a = np.array([5,2,4,7,8])
b = np.array([3,4,1,4,3])

area(a,b)
# Out:
# array([14., 12.])

# %%
array_gauss = np.random.normal(2,0.5,1000)

# %%
array_gauss
# Out:
# array([2.21400513, 2.32943094, 3.1427617 , 1.37794085, 2.48341214,
#        2.53939259, 1.44167684, 2.55108942, 1.04687999, 2.27925832,
#        2.12827437, 1.2109621 , 2.12918799, 1.69447597, 1.02947749,
#        1.35708823, 1.51873282, 1.25851309, 2.31756206, 2.63822222,
#        2.19265952, 2.56296105, 2.35111569, 1.63583718, 2.91195997,
#        2.30074123, 1.97974196, 2.91232046, 2.52757374, 1.75833484,
#        0.91005408, 1.7817007 , 2.21384314, 2.00582954, 2.20311794,
#        1.5813559 , 2.46414155, 2.02990708, 2.04385351, 2.17349608,
#        2.04025612, 2.12581897, 2.22750406, 3.50551171, 2.26096067,
#        1.71121034, 2.42522553, 1.22919377, 2.03192786, 1.14931954,
#        2.01709104, 2.10331085, 2.29607065, 1.79847838, 2.47063804,
#        2.92507465, 2.37761068, 1.65424245, 2.58259308, 1.52243911,
#        2.32133073, 1.94154806, 1.37179344, 1.91545072, 2.11186034,
#        1.69328767, 1.74119197, 1.41386843, 2.00448996, 2.13013193,
# ...

# %%
array1 = np.random.normal(3,1.5,10000)

# %%
array_perc = [np.mean(array1)-2*np.std(array1),np.mean(array1)+2*np.std(array1)]
array_perc
# Out:
# [-0.02016607235567891, 6.014339790058138]
